# %%
import pandas as pd
import os
import seaborn as sns
pd.read_csv("./landslide_catalog.csv")
temp=pd.read_csv("./landslide_catalog.csv")
days_of_month = temp["date"]
days_of_month=pd.to_datetime(days_of_month)
print(days_of_month)
print(type(days_of_month[0]))
print(type(days_of_month))
days_of_month=days_of_month.dt.day
print(days_of_month)
print(type(days_of_month[0]))
print(type(days_of_month))
sns.distplot(days_of_month,kde=False,bins=31)
# Out:
# 0      2007-03-02
# 1      2007-03-22
# 2      2007-04-06
# 3      2007-04-14
# 4      2007-04-15
#           ...
# 1688   2015-12-07
# 1689   2016-02-22
# 1690   2016-02-23
# 1691   2016-02-26
# 1692   2016-03-02
# Name: date, Length: 1693, dtype: datetime64[ns]
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas.core.series.Series'>
# 0        2.0
# 1       22.0
# 2        6.0
# 3       14.0
# 4       15.0
#         ...
# 1688     7.0
# 1689    22.0
# 1690    23.0
# 1691    26.0
# 1692     2.0
# Name: date, Length: 1693, dtype: float64
# <class 'numpy.float64'>
# <class 'pandas.core.series.Series'>
# <AxesSubplot:xlabel='date'>

# %%
import pandas as pd
import os
import chardet
print(os.path.abspath("./"))


#pd.read_csv("./lab04/ks-projects-201801.csv",encoding="Windows-1252")
pd.read_csv("./ks-projects-201801.csv")
# Out:
# c:\Users\nanos\repo\CS1056\lab04
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# ...            ...                                                ...
# 378656   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 378657   999977640                                          The Tribe
# 378658   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 378659   999987933                           BioDefense Education Kit
# 378660   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency    deadline     goal  \
# ...

# %%
import pandas as pd
import os
import chardet
print(os.path.abspath("./"))
#temp=pd.read_csv("./lab04/ks-projects-201801.csv")
temp=pd.read_csv("./Reviews.csv")
pd.read_csv("./Reviews.csv")
temp=temp.drop("Id",1)
origin_length = len(temp)
print(origin_length)
temp=temp.drop_duplicates(keep='first')
print(len(temp))
print(len(temp)/origin_length)
# Out:
# c:\Users\nanos\repo\CS1056\lab04
# 568454
# 568173
# 0.9995056768005854
